# %% [markdown]
# # AI Security Triage Assistant - Data Exploration
#
# ## Project Overview
#
# Cybersecurity teams generate large volumes of network events that must be analyzed to identify potential threats. This project explores how machine learning can assist security analysts by classifying network activity as either normal or malicious.
#
# The goal of this notebook is to understand the dataset, identify data quality issues, and prepare the foundation for building a machine learning classification model.
#
# ## Objectives
#
# In this notebook, we will:
#
# - Load and inspect the cybersecurity dataset
# - Understand the structure and features
# - Identify missing values and inconsistencies
# - Explore patterns in normal and malicious traffic
# - Prepare insights for the data preprocessing phase

# %%
# Data manipulation
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
file_path = "../data/UNSW_NB15_training-set.csv"

df = pd.read_csv(file_path)

df.head()
# Out:
#    id       dur proto service state  spkts  dpkts  sbytes  dbytes       rate  \
# 0   1  0.121478   tcp       -   FIN      6      4     258     172  74.087490
# 1   2  0.649902   tcp       -   FIN     14     38     734   42014  78.473372
# 2   3  1.623129   tcp       -   FIN      8     16     364   13186  14.170161
# 3   4  1.681642   tcp     ftp   FIN     12     12     628     770  13.677108
# 4   5  0.449454   tcp       -   FIN     10      6     534     268  33.373826
#
#    sttl  dttl         sload          dload  sloss  dloss      sinpkt  \
# 0   252   254  14158.942380    8495.365234      0      0   24.295600
# 1    62   252   8395.112305  503571.312500      2     17   49.915000
# 2    62   252   1572.271851   60929.230470      1      6  231.875571
# 3    62   252   2740.178955    3358.622070      1      3  152.876547
# 4   254   252   8561.499023    3987.059814      2      1   47.750333
#
#        dinpkt          sjit          djit  swin       stcpb       dtcpb  dwin  \
# ...
